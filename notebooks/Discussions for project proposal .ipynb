# %% [markdown]
# front page
#
# table of contents
#
# **abstract** : .....
#
# **intro** : no history, simple blockchain intro
#
# crypto hash fn , running time of hash fn, hashing works with any data str,
# sha-256 , immediately after add fig pg 43 book
#
# **explanation** :
#
# hashing basics
#
# explain how hash fn le unique output dina sakne hunu paro
#
# digital signature
#
# add code for something like this:
#
# > class SHA256(object):
#     def __init__(self, string=None):
#         self._sha = {
#             'digest': INITIAL_HASH,
#             'count_lo': 0,
#             'count_hi': 0,
#             'data': zeros(BLOCK_SIZE),
#         }
#
#
#  this is for cryptographic hash fn .
#
#  explain linked list structure
#
#
# genesis block (head of linked list)
#
#
# merkle tree (hash pointer le baneko binary tree)
#
# how are transaction going to be safe in the chain
#
# add nakamoto's picture from transactions from page 2 of paper
#
#
# timestamp
#
# proof of work
#
# distributed ledger  (transactions betn nodes is stored in this)
#
# copy of distrbtd ledger should be stored in every node
#
#
#
# mining: (related to proof of work) (transctn betn nodes to be added in blockchain, sable verify garna na pauna paro,
#
#
# decentralized app ( open src app, not governed by central body) (like matrix)
#
# ethereum ma math prblm jasle solve garna sako tesle verify garna pauxa)
#
# how much memory occupied etc, ...
#
# transaction rate
#
# privacy how maintained
# (2 types of ledger: permissioned and unpermissioned ) sable herna milne ra na milne
#
#
#
# **existing implementation** : cite satoshi bitcoin paper
#
# cite ethereum
#
# etc etc
#
# **conclusion** :
# ...
#
# **bibliography**:
